# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
day = pd.read_csv('day.csv')
hour = pd.read_csv('hour.csv')

# %%
day.infer_objects().dtypes
# Out:
# instant         int64
# dteday         object
# season          int64
# yr              int64
# mnth            int64
# holiday         int64
# weekday         int64
# workingday      int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object

# %%
(hour['temp']).min()
# Out:
# 0.02

# %%
day[day['holiday']==1].plot('instant','cnt', kind = 'scatter')
day[day['holiday']==0].plot('instant','cnt', kind = 'scatter')

# %%
day.dteday = pd.to_datetime(day.dteday)

# %%
day[day['holiday']==0].hist('cnt')
day[day['holiday']==1].hist('cnt')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000868FAC8>]],
#       dtype=object)

# %%
day.plot('temp','cnt', kind='scatter')
day.plot('atemp','cnt', kind='scatter')

# %%
day.plot('cnt','temp', kind='bar')

# %%
day.cnt.describe()
# Out:
# count     731.000000
# mean     4504.348837
# std      1937.211452
# min        22.000000
# 25%      3152.000000
# 50%      4548.000000
# 75%      5956.000000
# max      8714.000000
# Name: cnt, dtype: float64
